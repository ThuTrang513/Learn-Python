# %% [markdown]
# ## Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
plt.style.use("seaborn-v0_8-pastel")

# %%
plt.plot();

# %%
x = [1,2,3,4]
y = [10,8,6,9]
plt.plot(x, y, color = "red");

# %% [markdown]
# ### Pyplot API vs Object_Oriented (OO) API
# * Pyplot API -> quickly
# * OO API -> advance

# %% [markdown]
# ## Pyplot API

# %%
x = np.linspace(0,10,1000)
plt.plot(x,np.sin(x), color = "blue",linestyle = "dashed",label = "sin x")
plt.plot(x,np.cos(x), color = "red",label = "cos x")
plt.title("do thi")
plt.xlabel("x")
plt.ylabel("f(x)")

#plt.xlim(0,3)
#plt.ylim(0,2)

#plt.axis([xmin,xmax,ymin,ymax])
#plt.axis([0,3,0,2])
#plt.axis("tight")
#plt.axis("equal")

plt.legend();

# %% [markdown]
# ## OO API

# %%
#prepare data
x = [1,2,3,4]
y = [10,8,6,9]

#set up plot
fig, ax = plt.subplots(figsize=(5,9)) 

#plot
ax.plot(x,y);
ax.set(title = "simpe plot",
      xlabel = "x",
      ylabel = "y");

# %% [markdown]
# ## Most common types
# * line
# * scatter
# * bar
# * hist
# * suplots

# %%
# create line
x = np.linspace(0,10,100)

# %%
fig, ax = plt.subplots()
ax.plot(x,x**3)

# %% [markdown]
# # scatte
# * Biểu đồ phân tán

# %%
# pyplot api
plt.scatter(x,np.exp(x))

# %%
# OO API
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)
color = rng.rand(100)
sizes = 1000
fig, ax = plt.subplots()
img1 = ax.scatter(x,y,s=sizes, c=color, cmap = "viridis", alpha = 0.3)

fig.colorbar(img1)

# %% [markdown]
# ### BAR CHART
# * vertical
# * horizontal

# %%
soft_drink = {"cake": 10, "pessi":12, "sprite": 8}
fig,ax = plt.subplots()
ax.bar(soft_drink.keys(),soft_drink.values(),color = "red")
# Out:
# <BarContainer object of 3 artists>

# %%
fig,ax = plt.subplots()
ax.barh(list(soft_drink.keys()),list(soft_drink.values()))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## Histogram

# %%
np.random.seed(42)
student_height = np.random.normal(170,10,250) # 170: chieu cao tb, 10, do lech chuan, 250: 250 nguoi

# %%
#pyplot API
plt.hist(student_height, bins = 10);

# %% [markdown]
# #### SUBPLOTS

# %%
# Option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows = 2,ncols = 2,figsize = (10,5))

ax1.plot(x,x/2)
ax1.plot(x,x*2)

ax2.scatter(np.random.random(10),np.random.random(10))

ax3.bar(soft_drink.keys(),soft_drink.values(),color = "red")

ax4.hist(student_height, bins = 10);

# %%
#option1(n)
fig, ax = plt.subplots(nrows = 2,ncols = 2,figsize = (10,5))

ax[0][0].plot(x,x/2)
ax[0][0].plot(x,x*2)

ax[0][1].scatter(np.random.random(10),np.random.random(10))

ax[1][0].bar(soft_drink.keys(),soft_drink.values(),color = "red")

ax[0][1].hist(student_height, bins = 10);
